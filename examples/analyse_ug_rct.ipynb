# %%
import pandas as pd

# %%
household = pd.read_csv('~/Qsync/整理/Work/Uganda RCT/ISASimple_Gates_LLINE-UP_rct_RSRC_households.txt', sep='\t')
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (29,35,54,79,81,84,97,98,112,121,122,123) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
household.describe()
# Out:
#        Acres [EUPATH_0000026]  Bednet count [EUPATH_0020225]  \
# count            20668.000000                   20792.000000
# mean                12.002540                       2.405444
# std                284.025083                       1.592907
# min                  0.000000                       0.000000
# 25%                  1.000000                       1.000000
# 50%                  2.000000                       2.000000
# 75%                  3.000000                       3.000000
# max              10000.000000                      16.000000
#
#        Bednets per person [EUPATH_0020227]  \
# count                         20792.000000
# mean                              0.454338
# std                               0.278261
# min                               0.000000
# 25%                               0.290000
# 50%                               0.500000
# 75%                               0.600000
# max                               3.330000
#
# ...

# %%
household.head(10)
# Out:
#   Household_Id Community_Id 1 bednet per 2 people [EUPATH_0020219]  \
# 0  h_100101003          c_1                                     No
# 1  h_100101007          c_1                                     No
# 2  h_100101011          c_1                                     No
# 3  h_100101017          c_1                                     No
# 4  h_100101027          c_1                                     No
# 5  h_100102011          c_1                                    Yes
# 6  h_100102013          c_1                                     No
# 7  h_100102021          c_1                                     No
# 8  h_100102025          c_1                                     No
# 9  h_100102029          c_1                                     No
#
#   1 ITN per 2 people [EUPATH_0044135]  Acres [EUPATH_0000026]  \
# 0                                  No                     3.0
# 1                                  No                     1.0
# ...

# %%
observation = pd.read_csv('~/Qsync/整理/Work/Uganda RCT/ISASimple_Gates_LLINE-UP_rct_RSRC_observations.txt', sep='\t')

# %%
observation
# Out:
#              Observation_Id   Participant_Id Household_Id  Age [OBI_0001169]  \
# 0       o_10010100301_00m_1  10010100301_00m  h_100101003              45.00
# 1       o_10010100302_00m_1  10010100302_00m  h_100101003              35.00
# 2       o_10010100303_00m_1  10010100303_00m  h_100101003              19.00
# 3       o_10010100304_00m_1  10010100304_00m  h_100101003              18.00
# 4       o_10010100305_00m_1  10010100305_00m  h_100101003              16.00
# ...                     ...              ...          ...                ...
# 115537  o_41041009303_18m_4  41041009303_18m  h_410410093              17.00
# 115538  o_41041009304_18m_4  41041009304_18m  h_410410093              12.00
# 115539  o_41041009305_18m_4  41041009305_18m  h_410410093               9.00
# 115540  o_41041009306_18m_4  41041009306_18m  h_410410093               6.00
# 115541  o_41041009307_18m_4  41041009307_18m  h_410410093               0.67
#
# ...

# %%
metadata = pd.read_csv('~/Qsync/整理/Work/Uganda RCT/ISASimple_Gates_LLINE-UP_rct_RSRC_ontologyMetadata.txt', sep='\t')

# %%
metadata
# Out:
#                iri                    label    type          parentlabel  \
# 0    ENVO_00000004                  Country  string  Geographic location
# 1    ENVO_00000501                      Bed  string               Assets
# 2    ENVO_00003064    Drinking water source  string      Household water
# 3    ENVO_01000577                    Radio  string               Assets
# 4    ENVO_01000578          Cassette player  string               Assets
# ..             ...                      ...     ...                  ...
# 201    OBI_0002649  Blood microbiology test     NaN      Laboratory test
# 202    OBI_0400065          Lighting source  string  Dwelling facilities
# 203   OGMS_0000056          Laboratory test     NaN               Sample
# 204   PATO_0000047                      Sex  string         Demographics
# 205    PCO_0000024                Household     NaN                  NaN
#
#         category                                         definition  min  max  \
# ...

# %%
participants = pd.read_csv('~/Qsync/整理/Work/Uganda RCT/ISASimple_Gates_LLINE-UP_rct_RSRC_participants.txt', sep='\t')

# %%
participants
# Out:
#          Participant_Id Household_Id  \
# 0       21020705606_06m  h_210207056
# 1       30120506002_12m  h_301205060
# 2       30930107902_12m  h_309301079
# 3       30270904603_12m  h_302709046
# 4       30710405403_12m  h_307104054
# ...                 ...          ...
# 115537  10800405701_00m  h_108004057
# 115538  30640503904_12m  h_306405039
# 115539  40130401001_18m  h_401304010
# 115540  20340700604_06m  h_203407006
# 115541  10840209303_00m  h_108402093
#
#        Eligible for clinical survey [EUPATH_0044101]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
# ...                                              ...
# 115537                                            No
# 115538                                           Yes
# ...

# %%
participants.describe()
# Out:
#          Participant_Id Household_Id  \
# count            115542       115542
# unique           115542        20792
# top     30710209013_12m  h_309102095
# freq                  1           27
#
#        Eligible for clinical survey [EUPATH_0044101]  \
# count                                         115542
# unique                                             2
# top                                               No
# freq                                           72857
#
#        Household head age categorization (years) [EUPATH_0044151]  \
# count                                               29612
# unique                                                  4
# top                                           30-39 years
# freq                                                 8919
#
#        Household head's sex [EUPATH_0044152]  \
# count                                  29612
# unique                                     2
# top                                     Male
# ...

# %%
samples = pd.read_csv('~/Qsync/整理/Work/Uganda RCT/ISASimple_Gates_LLINE-UP_rct_RSRC_samples.txt', sep='\t')

# %%
samples
# Out:
#                   Sample_Id       Observation_Id   Participant_Id  \
# 0       s_10010100301_00m_1  o_10010100301_00m_1  10010100301_00m
# 1       s_10010100302_00m_1  o_10010100302_00m_1  10010100302_00m
# 2       s_10010100303_00m_1  o_10010100303_00m_1  10010100303_00m
# 3       s_10010100304_00m_1  o_10010100304_00m_1  10010100304_00m
# 4       s_10010100305_00m_1  o_10010100305_00m_1  10010100305_00m
# ...                     ...                  ...              ...
# 115537  s_41041009303_18m_4  o_41041009303_18m_4  41041009303_18m
# 115538  s_41041009304_18m_4  o_41041009304_18m_4  41041009304_18m
# 115539  s_41041009305_18m_4  o_41041009305_18m_4  41041009305_18m
# 115540  s_41041009306_18m_4  o_41041009306_18m_4  41041009306_18m
# 115541  s_41041009307_18m_4  o_41041009307_18m_4  41041009307_18m
#
#        Household_Id Anemia (hemoglobin less than 10g/dL) [EUPATH_0020209]  \
# 0       h_100101003  Did not consent / did not meet inclusion crite...
# ...

# %%
samples.describe()
# Out:
#        Hemoglobin (g/dL) [EUPATH_0000047]  \
# count                        13747.000000
# mean                            11.770685
# std                              1.468040
# min                              1.900000
# 25%                             10.900000
# 50%                             12.000000
# 75%                             12.700000
# max                             20.300000
#
#        Plasmodium asexual stages (per uL blood), by microscopy [EUPATH_0000092]
# count                                       32100.000000
# mean                                         1650.403769
# std                                         11906.090693
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                        674000.000000
